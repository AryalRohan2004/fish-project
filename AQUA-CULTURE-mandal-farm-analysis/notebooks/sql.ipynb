# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('mysql+mysqlconnector://root:admin@localhost:3306/mandal_farm')

# %%
with open('../sql/avg_oxygen_perpond.sql','r') as f:
    query = f.read()

result = pd.read_sql(query, engine)
print(result)
# Out:
#      Pond_ID  average_oxygen  average_ammonia  total_mortality
# 0  GrowOut-B            6.33             0.05            149.0
# 1  GrowOut-A            7.02             0.05            140.0
# 2    Nursery            7.13             0.05            108.0

# %%
with open('../sql/mortality_trend.sql','r') as f:
    query = f.read()

    result = pd.read_sql(query, engine)

    print(result)
# Out:
#       Pond_ID     months  mortality
# 0   GrowOut-B     August     47.000
# 1   GrowOut-A      March     42.125
# 2   GrowOut-A    January     37.000
# 3   GrowOut-B        May     36.000
# 4   GrowOut-A      April     35.125
# 5   GrowOut-B       June     34.000
# 6     Nursery   December     33.500
# 7   GrowOut-B       July     31.000
# 8     Nursery  September     29.000
# 9   GrowOut-A   February     24.750
# 10    Nursery    October     23.000
# 11    Nursery   November     22.500
# 12  GrowOut-A        May      1.000
# 13  GrowOut-B  September      1.000

# %%
with open('../sql/high_risk_days.sql','r') as f:
    query = f.read()

result = pd.read_sql(query, engine)

print(result)
# Out:
#          Date    Pond_ID  Water_Temp_C  Dissolved_Oxygen_mgL  Ammonia_ppm  \
# 0  2025-09-14    Nursery          32.9                  5.70         0.08
# 1  2025-09-13    Nursery          32.3                  6.50         0.03
# 2  2025-09-11    Nursery          32.4                  5.30         0.06
# 3  2025-09-04    Nursery          32.8                  6.20         0.04
# 4  2025-07-27  GrowOut-B          33.0                  5.50         0.02
# 5  2025-06-30  GrowOut-B          32.3                  5.30         0.08
# 6  2025-06-10  GrowOut-B          33.1                  6.00         0.01
# 7  2025-06-09  GrowOut-B          34.1                  5.70         0.05
# 8  2025-06-06  GrowOut-B          32.4                  4.95         0.07
# 9  2025-05-30  GrowOut-B          33.2                  5.70         0.05
# 10 2025-05-27  GrowOut-B          33.7                  6.00         0.03
# 11 2025-05-26  GrowOut-B          33.0                  5.70         0.04
# ...
