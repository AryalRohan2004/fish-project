# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv(r'D:\project\AQUA-CULTURE-mandal-farm-analysis\data\Master_Engineered_Mandal_Farm.csv')
df.head()
# Out:
#          Date    Pond_ID Pond_Type Target_Species  Season  Water_Temp_C  \
# 0  2025-01-01  GrowOut-A   Farming      Pangasius  Winter          17.0
# 1  2025-01-02  GrowOut-A   Farming      Pangasius  Winter          15.7
# 2  2025-01-03  GrowOut-A   Farming      Pangasius  Winter          15.5
# 3  2025-01-04  GrowOut-A   Farming      Pangasius  Winter          15.5
# 4  2025-01-05  GrowOut-A   Farming      Pangasius  Winter          19.2
#
#   Weather_Condition  Rainfall_mm  pH_Level  Ammonia_ppm  ...  \
# 0            Cloudy          0.0       7.9         0.05  ...
# 1             Sunny          0.0       6.6         0.02  ...
# 2             Sunny          0.0       7.4         0.03  ...
# 3            Cloudy          0.0       6.7         0.05  ...
# 4             Sunny          0.0       7.1         0.00  ...
#
#    Ammonia_Toxicity_Index  Stress_Index  Density_Oxygen_Pressure  \
# 0                0.038371      1.483714                 1.176471
# 1                0.011842      1.348423                 1.123483
# 2                0.019663      1.446629                 1.204337
# 3                0.029671      1.546714                 1.233951
# 4                0.000000      0.880000                 1.249250
#
#    Daily_Weight_Gain_g  Feed_Efficiency_FCR  Mortality_Rate_per_1000  \
# 0                  0.0             0.000000                  0.00000
# 1                  0.2            21.000000                  0.10001
# 2                  0.4            12.500000                  0.30012
# 3                  0.3            17.666667                  0.10005
# 4                  0.3            16.000000                  0.10006
#
#    Daily_Cost_Per_Fish_NPR  Month  Day_of_Month  Day_of_Year
# 0                 0.096500      1             1            1
# 1                 0.095510      1             2            2
# 2                 0.100440      1             3            3
# 3                 0.103652      1             4            4
# 4                 0.100660      1             5            5
#
# [5 rows x 35 columns]

# %%
df['Date']=pd.to_datetime(df['Date'])
df['Date']
# Out:
# 0     2025-01-01
# 1     2025-01-02
# 2     2025-01-03
# 3     2025-01-04
# 4     2025-01-05
#          ...
# 360   2025-12-27
# 361   2025-12-28
# 362   2025-12-29
# 363   2025-12-30
# 364   2025-12-31
# Name: Date, Length: 365, dtype: datetime64[ns]

# %%
# Out:
# 0     2025-01-01
# 1     2025-01-02
# 2     2025-01-03
# 3     2025-01-04
# 4     2025-01-05
#          ...
# 360   2025-12-27
# 361   2025-12-28
# 362   2025-12-29
# 363   2025-12-30
# 364   2025-12-31
# Name: Date, Length: 365, dtype: datetime64[ns]
